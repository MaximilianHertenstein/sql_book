# %% [markdown]
# # MySQL example (Binder)
# Run the setup cell (1) to start MySQL in the session and create the example database and user.
# Then run the SQL cell (2) to connect using the xeus-sql `%LOAD` magic.

# %%
# %%bash
# chmod +x start_mysql_server.sh || true
# ./start_mysql_server.sh

# %%
# %LOAD mysql host=127.0.0.1 port=3306 db=dbname user=user_simple password=password123
SELECT 'ok' AS connection_test;
